# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %% [markdown]
# 1. Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.

# %%
df_videogames = pd.read_csv("videogames.csv")

# %% [markdown]
# 2. Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_videogames
# Out:
#        Unnamed: 0                                 name  \
# 0               0                           Spider-Man
# 1               1               Red Dead Redemption II
# 2               2                   Grand Theft Auto V
# 3               3                           God of War
# 4               4           Uncharted 4: A Thief's End
# ...           ...                                  ...
# 20798       20798  Enjoy Your Power, Enjoy Your Choice
# 20799       20799                           RedSun2020
# 20800       20800                              Shutter
# 20801       20801                    The Music Machine
# 20802       20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 3. Una vez creado el Dataframe, muestra las 10 primeras filas.

# %%
df_videogames.head(10)
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
# 5           5     The Last of Us: Part II
# 6           6      Horizon Forbidden West
# 7           7              The Last of Us
# 8           8       Detroit: Become Human
# 9           9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...

# %% [markdown]
# 4. ¿Cúal es el último índice que tenemos en el Dataframe?

# %%
indice_videogrames = df_videogames.tail(1)
indice_videogrames
# Out:
#        Unnamed: 0     name                                                url  \
# 20802       20802  Cryptic  https://www.imdb.com/title/tt10964974/?ref_=ad...
#
#          year certificate  rating votes  \
# 20802  2020.0         NaN     NaN   NaN
#
#                                                     plot  Action  Adventure  \
# 20802  Kidnapped by an insane man and dragged into a ...   False      False
#
#        Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 20802   False  False   False    False    False   False      True

# %% [markdown]
# 5. Mostrar 15 filas aleatorias.

# %%
aleatorio_videogames = df_videogames.sample(15)
aleatorio_videogames
# Out:
#        Unnamed: 0                                            name  \
# 9745         9745                 Hatsune Miku: Gurafi korekushon
# 16709       16709                              Rafiki's Challenge
# 5967         5967  Densetsu no Yuusha no Densetsu: Legendary Saga
# 9474         9474                                  Death to Spies
# 14191       14191                            Down the Rabbit Hole
# 4538         4538                                       Tiny Tank
# 17302       17302                              Caribbean Hideaway
# 8767         8767                                       Dominator
# 11095       11095              Goblin Slayer: The Endless Revenge
# 20744       20744                            Rides with Strangers
# 3965         3965                                   Silver Surfer
# 12826       12826                                 Unearthing Mars
# 18806       18806                              Rubies of Eventide
# ...

# %% [markdown]
# 6. Crea una lista con el nombre de las columnas.

# %%
columnas_df = list(df_videogames.columns)
columnas_df
# Out:
# ['Unnamed: 0',
#  'name',
#  'url',
#  'year',
#  'certificate',
#  'rating',
#  'votes',
#  'plot',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Family',
#  'Fantasy',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller']

# %% [markdown]
# 7. Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
df_videogames.to_excel('videogames1.xlsx')

# %%
df_videogames
# Out:
#        Unnamed: 0                                 name  \
# 0               0                           Spider-Man
# 1               1               Red Dead Redemption II
# 2               2                   Grand Theft Auto V
# 3               3                           God of War
# 4               4           Uncharted 4: A Thief's End
# ...           ...                                  ...
# 20798       20798  Enjoy Your Power, Enjoy Your Choice
# 20799       20799                           RedSun2020
# 20800       20800                              Shutter
# 20801       20801                    The Music Machine
# 20802       20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 8. Muestra la "info" del Dataframe.

# %%
df_videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20803 entries, 0 to 20802
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   20803 non-null  int64
#  1   name         20803 non-null  object
#  2   url          20803 non-null  object
#  3   year         20536 non-null  float64
#  4   certificate  7903 non-null   object
#  5   rating       11600 non-null  float64
#  6   votes        11600 non-null  object
#  7   plot         20803 non-null  object
#  8   Action       20803 non-null  bool
#  9   Adventure    20803 non-null  bool
#  10  Comedy       20803 non-null  bool
#  11  Crime        20803 non-null  bool
#  12  Family       20803 non-null  bool
#  13  Fantasy      20803 non-null  bool
#  14  Mystery      20803 non-null  bool
#  15  Sci-Fi       20803 non-null  bool
#  16  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 9. ¿Tiene nulos o duplicados?

# %%
df_videogames.duplicated().sum() #No tiene duplicados
# Out:
# 0

# %%
df_videogames.isnull().sum() #Year, certificate, rating y votes tienen nulos
# Out:
# Unnamed: 0         0
# name               0
# url                0
# year             267
# certificate    12900
# rating          9203
# votes           9203
# plot               0
# Action             0
# Adventure          0
# Comedy             0
# Crime              0
# Family             0
# Fantasy            0
# Mystery            0
# Sci-Fi             0
# Thriller           0
# dtype: int64

# %% [markdown]
# 10. Obtener la descripción del Dataframe, tanto de las columnas numéricas cómo de las de tipo "object". Explorar el resultado y sacar unas mínimas comclusiones

# %%
df_videogames.describe(include='object')
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %%
df_videogames.describe()
# Out:
#          Unnamed: 0          year        rating
# count  20803.000000  20536.000000  11600.000000
# mean   10401.000000   2005.568611      7.047526
# std     6005.453161     11.846028      1.235204
# min        0.000000   1952.000000      1.000000
# 25%     5200.500000   1997.000000      6.400000
# 50%    10401.000000   2008.000000      7.200000
# 75%    15601.500000   2016.000000      7.900000
# max    20802.000000   2027.000000      9.700000

# %% [markdown]
# En objects nos ha sacado el recuento, los valores únicos y otros datos que tienen relaciones con los elementos no númericos, mientras que en el segundo nos saca todos los datos relacionados con valores númericos
# como el valor minímo/máximo y porcentajes.

# %% [markdown]
# 11. Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original.

# %%
df_videogames.to_csv('videogames2.csv')
